# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd

# %%
pd.set_option("display.float_format", lambda x: "%.3f" % x)
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 30)

# %%
df = pd.read_csv("C:/Users/Daniel/Documents/proyectos/riesgos/credit_scoring/train.csv")
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_16712\339568871.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/Daniel/Documents/proyectos/riesgos/credit_scoring/train.csv")

# %%
df.head(5)
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0      19114.12               1824.843                  3                4
# 1      19114.12                    NaN                  3                4
# 2      19114.12                    NaN                  3                4
# 3      19114.12                    NaN                  3                4
# 4      19114.12               1824.843                  3                4
#
#    Interest_Rate Num_of_Loan  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  object
#  3   Name                      90015 non-null   object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  object
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
# ...

# %%
df.columns = [column.lower() for column in df.columns]

# %%
df.describe(include = object).T
# Out:
#                           count  unique                               top  \
# id                       100000  100000                            0x1602
# customer_id              100000   12500                         CUS_0xd40
# month                    100000       8                           January
# name                      90015   10139                            Langep
# age                      100000    1788                                38
# ssn                      100000   12501                         #F%$D@*&8
# occupation               100000      16                           _______
# annual_income            100000   18940                          36585.12
# num_of_loan              100000     434                                 3
# type_of_loan              88592    6260                     Not Specified
# num_of_delayed_payment    92998     749                                19
# changed_credit_limit     100000    4384                                 _
# ...

# %%
df.describe().T
# Out:
#                               count     mean      std     min      25%  \
# monthly_inhand_salary     84998.000 4194.171 3183.686 303.645 1625.568
# num_bank_accounts        100000.000   17.091  117.405  -1.000    3.000
# num_credit_card          100000.000   22.474  129.057   0.000    4.000
# interest_rate            100000.000   72.466  466.423   1.000    8.000
# delay_from_due_date      100000.000   21.069   14.860  -5.000   10.000
# num_credit_inquiries      98035.000   27.754  193.177   0.000    3.000
# credit_utilization_ratio 100000.000   32.285    5.117  20.000   28.053
# total_emi_per_month      100000.000 1403.118 8306.041   0.000   30.307
#
#                               50%      75%       max
# monthly_inhand_salary    3093.745 5957.448 15204.633
# num_bank_accounts           6.000    7.000  1798.000
# num_credit_card             5.000    7.000  1499.000
# interest_rate              13.000   20.000  5797.000
# delay_from_due_date        18.000   28.000    67.000
# ...

# %% [markdown]
# ### Analysis continuous variables

# %%
um = ['id']

# %%
var_cont = ['monthly_inhand_salary','num_bank_accounts','num_credit_card','interest_rate','delay_from_due_date','num_credit_inquiries',
            'credit_utilization_ratio','total_emi_per_month']

# %%
columns = um + ['customer_id'] + var_cont

# %%
df1 =df[columns]

# %%
df1.head()
# Out:
#        id customer_id  monthly_inhand_salary  num_bank_accounts  \
# 0  0x1602   CUS_0xd40               1824.843                  3
# 1  0x1603   CUS_0xd40                    NaN                  3
# 2  0x1604   CUS_0xd40                    NaN                  3
# 3  0x1605   CUS_0xd40                    NaN                  3
# 4  0x1606   CUS_0xd40               1824.843                  3
#
#    num_credit_card  interest_rate  delay_from_due_date  num_credit_inquiries  \
# 0                4              3                    3                 4.000
# 1                4              3                   -1                 4.000
# 2                4              3                    3                 4.000
# 3                4              3                    5                 4.000
# 4                4              3                    6                 4.000
#
#    credit_utilization_ratio  total_emi_per_month
# 0                    26.823               49.575
# ...

# %%
df1['id'].duplicated().sum()
# Out:
# 0

# %%
df1.isna().sum().to_frame()
# Out:
#                               0
# id                            0
# customer_id                   0
# monthly_inhand_salary     15002
# num_bank_accounts             0
# num_credit_card               0
# interest_rate                 0
# delay_from_due_date           0
# num_credit_inquiries       1965
# credit_utilization_ratio      0
# total_emi_per_month           0

# %%
df1[var_cont].hist(figsize = (20,20))
# Out:
# array([[<Axes: title={'center': 'monthly_inhand_salary'}>,
#         <Axes: title={'center': 'num_bank_accounts'}>,
#         <Axes: title={'center': 'num_credit_card'}>],
#        [<Axes: title={'center': 'interest_rate'}>,
#         <Axes: title={'center': 'delay_from_due_date'}>,
#         <Axes: title={'center': 'num_credit_inquiries'}>],
#        [<Axes: title={'center': 'credit_utilization_ratio'}>,
#         <Axes: title={'center': 'total_emi_per_month'}>, <Axes: >]],
#       dtype=object)

# %%
# categoriza todas la variables
# busca como segmentar la variables de ingreso conrrectamente
# def range_income ()
